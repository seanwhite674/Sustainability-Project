# %% [markdown]
# ### Trying to use finite difference to solve this

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

# The below commands make the font and image size bigger
plt.rcParams.update({'font.size': 22})
plt.rcParams["figure.figsize"] = (15,10)

# %% [markdown]
# # Chegg Example

# %%
def tester(t,y):
    return [y[1],(-y[1]**2)/y[0]]

initderiv = np.linspace(10,50,10)

for el in initderiv:
    sol =solve_ivp(tester,[el,0],[1,0.01],rtol=1e-12,atol = 1e-12)
    y = sol.y
    t = sol.t
    plt.plot(t,y[0])
plt.scatter(0,0,s=100)

# %% [markdown]
# # With rain
# ## $f-\eta f' = (ff')'+1$

# %%
def testerGarcia(t,y):
    return [y[1],(y[0]-t*y[1]-y[1]**2-1)/y[0]]


initderiv = np.linspace(10,100,20)

for el in initderiv:
    sol =solve_ivp(tester,[el,0],[1,0.01],rtol=1e-12,atol = 1e-12)
    y = sol.y
    t = sol.t
    plt.plot(t,y[0],c='b')

sol = solve_ivp(tester,[50,100],[1,0.0001],rtol=1e-12,atol = 1e-12)
y = sol.y
t = sol.t
plt.plot(t,y[0],c='b')
plt.scatter(0,0,c='r')
#xs = np.linspace(31.7,100,20)
#ones = np.ones(20)
#plt.plot(xs,ones)

# %%
def testerGarcia(t,y):
    return [y[1],(y[0]-t*y[1]-y[1]**2-1)/y[0]]


initderiv = np.linspace(10,100,20)

el = 50
sol =solve_ivp(tester,[el,0],[1,0.01],rtol=1e-12,atol = 1e-12)
y = sol.y
t = sol.t
plt.plot(t,y[0],c='b')

sol = solve_ivp(tester,[50,100],[1,0.0001],rtol=1e-12,atol = 1e-12)
y = sol.y
t = sol.t
plt.plot(t,y[0],c='b') 
plt.scatter(0,0,c='r')

# %%
def testerGarcia(t,y):
    return [y[1],(y[0]-t*y[1]-y[1]**2-1)/y[0]]


initderiv = np.linspace(25,35,20)

for el in initderiv:
    sol =solve_ivp(tester,[el,0],[1,0],rtol=1e-12,atol = 1e-12)
    y = sol.y
    t = sol.t
    plt.plot(t,y[0],c='b')
    
plt.scatter(0,0,c='r')
#xs = np.linspace(31.7,100,20)
#ones = np.ones(20)
#plt.plot(xs,ones)

# %%
def testerGarcia(t,y):
    return [y[1],((y[0]-t*y[1]-y[1]**2-1)/y[0])]

endpoint = np.linspace(0,100,10)

end = 100

sol =solve_ivp(testerGarcia,[end,0],[1,0],rtol=1e-12,atol = 1e-12)
y = sol.y
t = sol.t
plt.plot(t,y[0],c='b')

plt.scatter(0,0,c='r')

# %%
elements = np.linspace(30,35,10)
yx1 = np.array([])

for el in elements:
    sol =solve_ivp(tester,[el,0],[1,0],rtol=1e-12,atol = 1e-12)
    yx1 = np.append(yx1, sol.y[0][-1])

plt.plot(elements,yx1,'.')

# %%
print(yx1)
# Out:
# [3.16227766e-01 2.57600514e-01 1.79161283e-01 1.48739138e-08
#  5.96134344e-08 8.35787851e-08 8.36218773e-08 1.18406510e-07
#  1.18379494e-07 1.18320990e-07]

# %%
f = y[0]
df = y[1]

print(f)
# Out:
# [1.00000000e+00 9.99999977e-01 9.99997233e-01 ... 2.14687377e-08
#  2.12633397e-08 2.10559382e-08]

# %%
print(df)
# Out:
# [0.00000000e+00 6.76243353e-06 7.43869730e-05 ... 1.47296860e+06
#  1.48719707e+06 1.50184600e+06]

# %%
f[100]*df[100]
# Out:
# 0.02708505576247379

# %%
f[200]*df[200]
# Out:
# 0.031131663145318237

# %%
f[300]*df[300]
# Out:
# 0.03157591606599968

# %%
np.sqrt(2*0.03)
# Out:
# 0.2449489742783178

# %%
c = 0.25

# %%
c**2/2
# Out:
# 0.03125
